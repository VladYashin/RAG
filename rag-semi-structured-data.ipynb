# %%
# import modules

from langchain.llms.openai import OpenAI
from langchain.vectorstores import FAISS
from langchain.sql_database import SQLDatabase
import os
from langchain.prompts import ChatPromptTemplate

from langchain.vectorstores.chroma import Chroma

# MongoDB
from dotenv import load_dotenv
from pymongo import MongoClient

# user query embedding
from sentence_transformers import SentenceTransformer
from langchain.document_loaders import UnstructuredURLLoader

# %%
# config Mongo DB

load_dotenv()

MONGO_USERNAME = os.environ.get('MONGO_USERNAME')
MONGO_PASSWORD = os.environ.get('MONGO_PASSWORD')
MONGO_HOST = os.environ.get('MONGO_HOST')
MONGO_DB_CONNECTION_STRING = os.environ.get('MONGO_DB_CONNECTION_STRING')
MONGO_DB = os.environ.get('MONGO_DB')
MONGO_DB_COLLECTION = "InventoryData"

# %%
# connect to Mongo DB

client = MongoClient(MONGO_DB_CONNECTION_STRING)
db = client[MONGO_DB]
collections = db.list_collection_names()

inventory_coll = db['InventoryData']

print(f'Collection: {inventory_coll.name}')
print(f"Total no. of docs: {inventory_coll.count_documents({})}")
# Out:
# Collection: InventoryData
# Total no. of docs: 538

# %%
# user query embedding function

emb_model = SentenceTransformer("thenlper/gte-large")

def get_embedding(text: str) -> list[float]:

    if not text.strip():
        print("Attempted to get embedding for empty text.")
        return []

    embedding = emb_model.encode(text)

    return embedding.tolist()

# %% [markdown]
# ## Classical Search

# %%
# keyword search

def search(search_text):
    data = inventory_coll.find({"$text": {"$search": search_text}}).limit(3)
    return list(data)

data = search('Servo-i')

for x in data:
    print(x)
# Out:
# {'_id': ObjectId('6620e804924de81c6030e9df'), 'Item Code': 'BP0001', 'Item Description': 'Batteries/ UPS', 'Part No': {'': '01-2206-0101-001'}, 'Part Description': 'BATTERY SERVO-I MARQUET', 'Model': 'Servo-i', 'Unit Of Measurement': 'Unit', 'Spare Part Type': 'Just In Time', 'Location': 'Centralized', 'Part Category': 'Biomedical', 'Is Expiry date Required': 'Yes', 'Min Nos': 0, 'Max Nos': 20, ' Minimum Price Per Nos (RM) ': ' MYR 1.200,00 ', ' Maximum Price Per Nos (RM) ': ' MYR 1.610,00 ', 'Status': 'Active', 'Expiry Age (In Month)': 0, 'Current Stock Level': 1}
# {'_id': ObjectId('6620e804924de81c6030e9ee'), 'Item Code': 'BP0025', 'Item Description': 'Sensors/ Detectors', 'Part No': {'': '01-2202-0302-001'}, 'Part Description': 'SIEMENS SERVO 9000 OXYGEN SENSOR OOM202', 'Model': 'Sv300', 'Unit Of Measurement': 'Unit', 'Spare Part Type': 'Fast Moving Item', 'Location': 'Company Site Office', 'Part Category': 'Biomedical', 'Is Expiry date Required': 'Yes', 'Min Nos': 1, 'Max Nos': 15, ' Minimum Price Per Nos (RM) ': ' MYR 159,85 ', ' Maximum Price Per Nos (RM) ': ' MYR 218,50 ', 'Brand': 'Siemens', 'Status': 'Active', 'Expiry Age (In Month)': 0, 'Current Stock Level': 0}

# %% [markdown]
# ## Semantic Search

# %%
# fetch all docs from InventoryData
def fetch_all_documents():
    data = inventory_coll.find({})
    return list(data)

data = fetch_all_documents()
data
# Out:
# [{'_id': ObjectId('6620e804924de81c6030e9c0'),
#   'Item Code': 'BP0018',
#   'Item Description': 'Motors/ Micromotors/ Carbon brushes',
#   'Part No': {'': '01-0802-0503-085'},
#   'Part Description': 'Flow motor',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 500,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 800,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9c1'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-0101-0101-044'},
#   'Part Description': 'O2 Sensor OOM202',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 280,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 380,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9c2'),
#   'Item Code': 'BP0005',
#   'Item Description': 'Casing/ Covers/ Brackets/ Latches/ Part Holders',
#   'Part No': {'': '01-0802-0504-011'},
#   'Part Description': 'Door 22MM Bubble C.Holder 4008SV10',
#   'Model': 'Fresenius 4008S NG',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 800,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 826,80 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 3},
#  {'_id': ObjectId('6620e804924de81c6030e9c3'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-0503-0104-001'},
#   'Part Description': 'Battery Pack Fot Tec 7731K',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 650,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.400,00 ',
#   'Brand': 'Nihon Kohden',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030e9c4'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-1603-1405-001'},
#   'Part Description': 'DATEX OHMEDA Spo2 FINGER SENSOR Trusignal (TS-F-D)',
#   'Model': 'Trusat',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 385,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 393,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 10},
#  {'_id': ObjectId('6620e804924de81c6030e9c5'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-0101-0600-002'},
#   'Part Description': 'FLOW TRANDUCER GE',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 450,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 790,00 ',
#   'Brand': 'Ge',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9c6'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1902-0301-002'},
#   'Part Description': 'Bulb 12v 30w',
#   'Model': 'Bc 900',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 16,
#   ' Minimum Price Per Nos (RM) ': ' MYR 127,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 130,00 ',
#   'Brand': 'Haag-Streit',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 24},
#  {'_id': ObjectId('6620e804924de81c6030e9c7'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-2300-0201-001'},
#   'Part Description': 'Battery AA (Alkaline)',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 200,
#   'Max Nos': 800,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1,85 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2,24 ',
#   'Brand': 'Energizer',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 595},
#  {'_id': ObjectId('6620e804924de81c6030e9c8'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0322-0101-015'},
#   'Part Description': 'Label Remover',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 12,
#   'Max Nos': 24,
#   ' Minimum Price Per Nos (RM) ': ' MYR 25,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 60,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9c9'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-2406-0401-001'},
#   'Part Description': 'Bulb 12v 100w (64623 HLX)',
#   'Model': 'Hlx64625',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 85,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 550,00 ',
#   'Brand': 'Osram',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 3,
#   'Current Stock Level': 10},
#  {'_id': ObjectId('6620e804924de81c6030e9ca'),
#   'Item Code': 'BP0027',
#   'Item Description': 'Switchs/ Knobs/Buttons',
#   'Part No': {'': '01-2406-0101-002'},
#   'Part Description': 'Read Switch',
#   'Model': 'Kcd-10m-7',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 80,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 85,00 ',
#   'Brand': 'TOSHIBA',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9cb'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0322-0101-006'},
#   'Part Description': 'STP Foam Cleaner',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 12,
#   'Max Nos': 24,
#   ' Minimum Price Per Nos (RM) ': ' MYR 27,50 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 75,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 17},
#  {'_id': ObjectId('6620e804924de81c6030e9cc'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0322-0200-001'},
#   'Part Description': 'Ambersil - Label Remover',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 12,
#   'Max Nos': 24,
#   ' Minimum Price Per Nos (RM) ': ' MYR 42,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 250,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 13},
#  {'_id': ObjectId('6620e804924de81c6030e9cd'),
#   'Item Code': 'BP0014',
#   'Item Description': 'Hoses/ Tubings/ Adaptors/ Couplers/ Connectors/ Pipes',
#   'Part No': {'': '01-2305-0102-001'},
#   'Part Description': 'Swive Air Hose',
#   'Model': 505,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 1,
#   ' Minimum Price Per Nos (RM) ': ' MYR 600,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 650,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9ce'),
#   'Item Code': 'BP0018',
#   'Item Description': 'Motors/ Micromotors/ Carbon brushes',
#   'Part No': {'': '01-0802-0502-007'},
#   'Part Description': 'Fresenius 4008S Motor Assy Degassing Complete',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 10,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.000,00 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9cf'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-2602-0200-018'},
#   'Part Description': 'PROJECTION LAMP 24V 250W OSRAM',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 9,50 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 10,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 18},
#  {'_id': ObjectId('6620e804924de81c6030e9d0'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1301-0601-001'},
#   'Part Description': 'Bulb 12V 50W',
#   'Model': 'M650',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 185,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 190,00 ',
#   'Brand': 'Leica',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9d1'),
#   'Item Code': 'BP0027',
#   'Item Description': 'Switchs/ Knobs/Buttons',
#   'Part No': {'': '01-0802-0502-021'},
#   'Part Description': 'Fresenius 4008S Float Switch Complete',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 172,04 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 190,00 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9d2'),
#   'Item Code': 'BP0026',
#   'Item Description': 'Solenoids/ Valves/ Gauges',
#   'Part No': {'': '01-0802-0503-035'},
#   'Part Description': 'Fresenius 4008S Reliief valve completed',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 179,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 197,00 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9d3'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-1603-1710-003'},
#   'Part Description': 'SPO2 REUSABLE SENSOR PEDIATRIC LNCS DCIP',
#   'Model': 'Radical 7',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 700,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 750,00 ',
#   'Brand': 'MASIMO',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 4},
#  {'_id': ObjectId('6620e804924de81c6030e9d4'),
#   'Item Code': 'BP0021',
#   'Item Description': 'Power Cords/ Adaptors (or any part of it)',
#   'Part No': {'': '01-0322-0101-005'},
#   'Part Description': 'COMMON ITEM POWER CORD 3 MTR',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 19,50 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 37,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 21},
#  {'_id': ObjectId('6620e804924de81c6030e9d5'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-1700-0000-001'},
#   'Part Description': 'EQUIPMENT SPECIFIC PARTS (IN HOUSE)',
#   'Model': 'Trinias C12/F12',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 10.001,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 100.000,00 ',
#   'Brand': 'Shimadzu',
#   'Status': 'Active',
#   'Current Stock Level': 5},
#  {'_id': ObjectId('6620e804924de81c6030e9d6'),
#   'Item Code': 'BP0014',
#   'Item Description': 'Hoses/ Tubings/ Adaptors/ Couplers/ Connectors/ Pipes',
#   'Part No': {'': '01-1909-0205-002'},
#   'Part Description': 'Male & Female Connector',
#   'Model': 'Dekamet MK3',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 10,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 2,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2,50 ',
#   'Brand': 'Accoson',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 46},
#  {'_id': ObjectId('6620e804924de81c6030e9d7'),
#   'Item Code': 'BP0006',
#   'Item Description': 'Cuffs',
#   'Part No': {'': '01-0203-0102-010'},
#   'Part Description': 'X-Large Cuff Adult 1 TB',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 10,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 10,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 13,00 ',
#   'Brand': 'Critikon/Velcro',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 23},
#  {'_id': ObjectId('6620e804924de81c6030e9d8'),
#   'Item Code': 'BP0012',
#   'Item Description': 'Filters',
#   'Part No': {'': '01-0802-0203-001'},
#   'Part Description': 'Diacap Ultra DF - Online Filter',
#   'Model': 7102001,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 10,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 370,00 ',
#   'Brand': 'B.Braun',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 10},
#  {'_id': ObjectId('6620e804924de81c6030e9d9'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1201-0103-005'},
#   'Part Description': 'Lamp for Laryngoscope',
#   'Model': 'Welch Allyn',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 3,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 26,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 60,00 ',
#   'Brand': 'Welch Allyn',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 5},
#  {'_id': ObjectId('6620e804924de81c6030e9da'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-1909-0102-005'},
#   'Part Description': 'Rechargeable Battery 12V 700Mah',
#   'Model': 5200,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 150,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 200,00 ',
#   'Brand': 'Top',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 11},
#  {'_id': ObjectId('6620e804924de81c6030e9db'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0503-0102-012'},
#   'Part Description': 'NIHON KOHDEN CHEST ELECTROLUDE ADULT COMPLEX',
#   'Model': '6851k',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 100,
#   ' Minimum Price Per Nos (RM) ': ' MYR 60,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 92,00 ',
#   'Brand': 'Nihon Kohden',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 16},
#  {'_id': ObjectId('6620e804924de81c6030e9dc'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1902-0601-001'},
#   'Part Description': 'BULB 6V 20W',
#   'Model': 'Sl-D Series',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 165,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 241,50 ',
#   'Brand': 'Topcon',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9dd'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1502-0101-008'},
#   'Part Description': 'Bulb WELCH ALLYN 03100',
#   'Model': 'Welch Allyn',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 35,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 55,20 ',
#   'Brand': 'Welch Allyn',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030e9de'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1503-0301-001'},
#   'Part Description': '3.5v Streak Lamp 08200',
#   'Model': 71670,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 35,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 69,00 ',
#   'Brand': 'Welch Allyn',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 9},
#  {'_id': ObjectId('6620e804924de81c6030e9df'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-2206-0101-001'},
#   'Part Description': 'BATTERY SERVO-I MARQUET',
#   'Model': 'Servo-i',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1.200,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.610,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9e0'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-1604-2602-001'},
#   'Part Description': 'BATTERY LITHIUM ION',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 1,
#   ' Minimum Price Per Nos (RM) ': ' MYR 650,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.035,00 ',
#   'Brand': 'PHILIPS',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 4},
#  {'_id': ObjectId('6620e804924de81c6030e9e1'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1604-2607-001'},
#   'Part Description': 'Transpac IV Cable HP PHILIPS',
#   'Model': 'GE',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 100,
#   ' Minimum Price Per Nos (RM) ': ' MYR 250,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 500,00 ',
#   'Brand': 'Philips',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 4},
#  {'_id': ObjectId('6620e804924de81c6030e9e2'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1604-2603-001'},
#   'Part Description': 'SPO2 Adult Finger Clip Sensor M1196A',
#   'Model': 'SureSigns VSi',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 700,00 ',
#   'Brand': 'Philips',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9e3'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-1909-0902-001'},
#   'Part Description': 'Battery 6v 2200 mah',
#   'Model': 'Injectomat Agilia',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 140,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 500,00 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9e4'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1203-0201-001'},
#   'Part Description': '300 Watts Xenon Lamp',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1.330,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.667,50 ',
#   'Brand': 'Olympus',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9e5'),
#   'Item Code': 'BP0006',
#   'Item Description': 'Cuffs',
#   'Part No': {'': '01-1601-1301-007'},
#   'Part Description': 'CUFF S/H ADULT (PHILIPS)',
#   'Model': 'V24 (Pm)',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 90,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 300,00 ',
#   'Brand': 'AGILENT',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 13},
#  {'_id': ObjectId('6620e804924de81c6030e9e6'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-2202-1402-001'},
#   'Part Description': 'Oxygen Sensor',
#   'Model': 'Servo-i',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 9,
#   ' Minimum Price Per Nos (RM) ': ' MYR 700,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.380,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9e7'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0502-0106-001'},
#   'Part Description': 'POWER CORD 5 METER 3 PIN',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 0,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 27,50 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 50,00 ',
#   'Brand': 'Erbe',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9e8'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0909-0200-002'},
#   'Part Description': 'Power Board',
#   'Model': 'Or-1500h',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 720,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.000,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030e9e9'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1604-2604-002'},
#   'Part Description': 'Cable 5 leadset grabber M1971A',
#   'Model': 'SureSigns VM4',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 480,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 715,00 ',
#   'Brand': 'Philips',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9ea'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-1700-0000-002'},
#   'Part Description': 'MAINTAINANCE SPARE PART (IN HOUSE)',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 7,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 22.000,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 3},
#  {'_id': ObjectId('6620e804924de81c6030e9eb'),
#   'Item Code': 'BP0006',
#   'Item Description': 'Cuffs',
#   'Part No': {'': '01-0203-0301-016'},
#   'Part Description': 'Cuff Connector Female',
#   'Model': 'Bp8800',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 3,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 7,00 ',
#   'Brand': 'COLIN',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 3},
#  {'_id': ObjectId('6620e804924de81c6030e9ec'),
#   'Item Code': 'BP0012',
#   'Item Description': 'Filters',
#   'Part No': {'': '01-1805-0101-003'},
#   'Part Description': 'Cotton Filter-20 Inch',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 15,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 32,20 ',
#   'Brand': 'Waterman',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 20},
#  {'_id': ObjectId('6620e804924de81c6030e9ed'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0203-0902-002'},
#   'Part Description': 'MINDRAY SPO2 Extension Cable, Sensor 2.4m (0010-20-42594)',
#   'Model': 'Pm 600',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 110,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 120,00 ',
#   'Brand': 'Mindray',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 23},
#  {'_id': ObjectId('6620e804924de81c6030e9ee'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-2202-0302-001'},
#   'Part Description': 'SIEMENS SERVO 9000 OXYGEN SENSOR OOM202',
#   'Model': 'Sv300',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 159,85 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 218,50 ',
#   'Brand': 'Siemens',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9ef'),
#   'Item Code': 'BP0010',
#   'Item Description': 'Electronic Components',
#   'Part No': {'': '01-0322-0101-017'},
#   'Part Description': 'PETTY CASH',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 36,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 500,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 57},
#  {'_id': ObjectId('6620e804924de81c6030e9f0'),
#   'Item Code': 'BP0006',
#   'Item Description': 'Cuffs',
#   'Part No': {'': '01-0203-0301-017'},
#   'Part Description': 'Cuff Connector Male',
#   'Model': 'Bp8800',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 3,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 6,00 ',
#   'Brand': 'COLIN',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 11},
#  {'_id': ObjectId('6620e804924de81c6030e9f1'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-1909-0101-001'},
#   'Part Description': 'Rechargeable Battery',
#   'Model': 'Top 5100',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 2,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 140,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 168,00 ',
#   'Brand': 'Top',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9f2'),
#   'Item Code': 'BP0026',
#   'Item Description': 'Solenoids/ Valves/ Gauges',
#   'Part No': {'': '01-2202-0201-002'},
#   'Part Description': 'Vent. Exhalation Valve Assy',
#   'Model': 8400,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 854,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.708,00 ',
#   'Brand': 'BIRD',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9f3'),
#   'Item Code': 'BP0026',
#   'Item Description': 'Solenoids/ Valves/ Gauges',
#   'Part No': {'': '01-0802-0503-206'},
#   'Part Description': 'VALVE SPRING SET BIC-4008/S V10',
#   'Model': 'Fresenius 4008 NG',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 5,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 100,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 300,00 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Current Stock Level': 8},
#  {'_id': ObjectId('6620e804924de81c6030e9f4'),
#   'Item Code': 'BP0005',
#   'Item Description': 'Casing/ Covers/ Brackets/ Latches/ Part Holders',
#   'Part No': {'': '01-0903-0202-016'},
#   'Part Description': 'Battery Cover Assembly ,TOP 3300',
#   'Model': 'Top 3300',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 3,
#   'Max Nos': 6,
#   ' Minimum Price Per Nos (RM) ': ' MYR 257,15 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 334,10 ',
#   'Brand': 'TOP',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 4},
#  {'_id': ObjectId('6620e804924de81c6030e9f5'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-2202-0000-001'},
#   'Part Description': 'Oxygen Sensor',
#   'Model': 7200,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1.200,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.380,00 ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9f6'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-0903-0202-001'},
#   'Part Description': 'Drop Sensor TOP 3300 (89T) T6330522',
#   'Model': 'Top 3300',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 718,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 825,70 ',
#   'Brand': 'Top',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9f7'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0803-0105-003'},
#   'Part Description': '900MR858 Electrical Adaptor',
#   'Model': 'Mr850',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 3,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 298,80 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 343,62 ',
#   'Brand': 'Fisher & Paykel',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030e9f8'),
#   'Item Code': 'BP0026',
#   'Item Description': 'Solenoids/ Valves/ Gauges',
#   'Part No': {'': '01-0802-0503-010'},
#   'Part Description': 'Solenoid Valve (Chamber)',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 1,
#   'Max Nos': 2,
#   ' Minimum Price Per Nos (RM) ': ' MYR 370,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 425,50 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 8},
#  {'_id': ObjectId('6620e804924de81c6030e9f9'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1604-2601-002'},
#   'Part Description': 'ECG 3 LEAD TRUNK CABLE',
#   'Model': 'IntelliVue MP40',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 500,00 ',
#   'Brand': 'Philips',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 10},
#  {'_id': ObjectId('6620e804924de81c6030e9fa'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-2202-1103-004'},
#   'Part Description': 'ANASTHESIA',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 200,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 275,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 13},
#  {'_id': ObjectId('6620e804924de81c6030e9fb'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1604-2604-001'},
#   'Part Description': 'Cable 5 lead ECG trunk M1668A',
#   'Model': 'SureSigns VM4',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 5,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 500,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 650,00 ',
#   'Brand': 'Philips',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030e9fc'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-0101-0101-045'},
#   'Part Description': 'Oxygen Sensor (OOM102-1)',
#   'Model': 'Elite 615',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'Yes',
#   'Min Nos': 3,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 320,00 ',
#   'Brand': 'ULCO',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 6,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9fd'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-0203-0909-001'},
#   'Part Description': 'Rechargeable Battery 11.1V, Mindray iMEC8',
#   'Model': 'Mindray iMEC8',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 400,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 450,00 ',
#   'Brand': 'Mindray',
#   'Status': 'Active',
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030e9fe'),
#   'Item Code': 'BP0012',
#   'Item Description': 'Filters',
#   'Part No': {'': '01-0802-0503-001'},
#   'Part Description': 'Diasafe Plus Filter',
#   'Model': '4008s',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 60,
#   ' Minimum Price Per Nos (RM) ': ' MYR 200,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 242,50 ',
#   'Brand': 'Fresenius',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030e9ff'),
#   'Item Code': 'BP0023',
#   'Item Description': 'PPM/ Service/Maintenance/ Repair Kits',
#   'Part No': {'': '01-0802-0503-014'},
#   'Part Description': 'Fresenius 4008S PPM Kit Yearly',
#   'Model': '4008s',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 35,
#   ' Minimum Price Per Nos (RM) ': ' MYR 500,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 530,00 ',
#   'Brand': 'FRESENIUS',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea00'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1505-0302-001'},
#   'Part Description': 'Bulb 24 V 150 W, OSRAM',
#   'Model': 'Osram',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 6,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 6,70 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 7,60 ',
#   'Brand': 'Osram',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea01'),
#   'Item Code': 'BP0006',
#   'Item Description': 'Cuffs',
#   'Part No': {'': '01-2002-1001-003'},
#   'Part Description': 'Cuff Cylindrical 34 Ats',
#   'Model': 'Common',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 2,
#   ' Minimum Price Per Nos (RM) ': ' MYR 400,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 460,00 ',
#   'Brand': 'Common',
#   'Status': 'Active',
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea02'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-2203-0601-002'},
#   'Part Description': 'SIPAP MACHINE OXYGEN SENSOR FABIAN OOM204',
#   'Model': 'Fabian',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 12,
#   ' Minimum Price Per Nos (RM) ': ' MYR 450,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 480,00 ',
#   'Brand': 'Acutronic',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea03'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0503-0501-002'},
#   'Part Description': 'SCHILLER 10 LEAD ECG CABLE BANANA TYPE',
#   'Model': 'Cardiovit AT-1',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 30,
#   ' Minimum Price Per Nos (RM) ': ' MYR 120,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 150,00 ',
#   'Brand': 'SCHILLER',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea04'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-2404-0101-003'},
#   'Part Description': 'Bulb 12V 100W (64627)',
#   'Model': 'Polydoros',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 3,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 10,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 11,50 ',
#   'Brand': 'Siemens',
#   'Status': 'Active',
#   'Current Stock Level': 9},
#  {'_id': ObjectId('6620e804924de81c6030ea05'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-1619-0200-004'},
#   'Part Description': 'MMS Module',
#   'Model': 'IntelliVue MP70',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 2,
#   ' Minimum Price Per Nos (RM) ': ' MYR 2.700,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2.800,00 ',
#   'Status': 'Active',
#   'Current Stock Level': 3},
#  {'_id': ObjectId('6620e804924de81c6030ea06'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-0903-0103-005'},
#   'Part Description': 'BATTERY B. BRAUN INFUSOMAT',
#   'Model': 'Infusomat',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 3,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 200,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 220,00 ',
#   'Brand': 'B.Braun',
#   'Status': 'Active',
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea07'),
#   'Item Code': 'BP0025',
#   'Item Description': 'Sensors/ Detectors',
#   'Part No': {'': '01-1603-0102-002'},
#   'Part Description': 'Spo2 Sensor Adult Original DS100A',
#   'Model': 'N-190',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 8,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 400,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 430,00 ',
#   'Brand': 'Nellcor',
#   'Status': 'Active',
#   'Current Stock Level': 6},
#  {'_id': ObjectId('6620e804924de81c6030ea08'),
#   'Item Code': 'BP0024',
#   'Item Description': 'Printed Circuit Boards (PCB; Other than Power Supply)',
#   'Part No': {'': '01-0503-1103-001'},
#   'Part Description': 'MODULE MONTARA AM-12',
#   'Model': 'Eli 280',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 2,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 2.000,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2.300,00 ',
#   'Status': 'Active',
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ea09'),
#   'Item Code': 'BP0028',
#   'Item Description': 'Transducers/ Probes',
#   'Part No': {'': '01-0303-0102-001'},
#   'Part Description': 'Ultrasound Tranducer',
#   'Model': 'M1353a',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 1,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1.300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 1.400,00 ',
#   'Brand': 'Hewlett Packard',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2},
#  {'_id': ObjectId('6620e804924de81c6030ea0a'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1601-1204-006'},
#   'Part Description': 'ECG TRUNK CABLE PROPAQ LT 3 LEAD',
#   'Model': 'Propaq LT',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 3,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 100,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 125,00 ',
#   'Brand': 'Welch Allyn',
#   'Status': 'Active',
#   'Current Stock Level': 4},
#  {'_id': ObjectId('6620e804924de81c6030ea0b'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0102-0104-028'},
#   'Part Description': 'EXTENSION CABLE TRUSIGNAL GE WITH CONNECTOR',
#   'Model': 'Aestiva 5/7100',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 2,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 100,00 ',
# ...
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 300,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 345,00 ',
#   'Brand': 'HEWLETT PACKARD',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc2'),
#   'Item Code': 'BP0024',
#   'Item Description': 'Printed Circuit Boards (PCB; Other than Power Supply)',
#   'Part No': {'': '01-0503-0302-013'},
#   'Part Description': 'Mother Board Unit',
#   'Model': 106,
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 38,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 43,70 ',
#   'Brand': 'SUZUKEN',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc3'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-0503-0801-001'},
#   'Part Description': 'Battery 9.6V 1100mAH w/out connector',
#   'Model': 'Fx2111',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 80,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 92,00 ',
#   'Brand': 'Fukuda',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc4'),
#   'Item Code': 'BP0001',
#   'Item Description': 'Batteries/ UPS',
#   'Part No': {'': '01-0609-0000-001'},
#   'Part Description': 'Battery for Entral feeding',
#   'Model': 'Kangaroo 924',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 60,
#   ' Minimum Price Per Nos (RM) ': ' MYR 80,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 92,00 ',
#   'Brand': 'KANGAROO',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 8},
#  {'_id': ObjectId('6620e804924de81c6030ebc5'),
#   'Item Code': 'BP0010',
#   'Item Description': 'Electronic Components',
#   'Part No': {'': '01-0802-0101-025'},
#   'Part Description': 'Relay Solid State',
#   'Model': 'Sps450/550',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 4,
#   ' Minimum Price Per Nos (RM) ': ' MYR 40,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 46,00 ',
#   'Brand': 'BAXTER',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc6'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-0802-0101-038'},
#   'Part Description': 'Patient Cable',
#   'Model': 'Sps450/550',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 4,
#   ' Minimum Price Per Nos (RM) ': ' MYR 276,10 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 317,52 ',
#   'Brand': 'BAXTER',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc7'),
#   'Item Code': 'BP0005',
#   'Item Description': 'Casing/ Covers/ Brackets/ Latches/ Part Holders',
#   'Part No': {'': '01-1601-0402-005'},
#   'Part Description': 'DATASCOPE BEZEL FRONT HIGHT ASSEMBLY 0380-00-0359-04',
#   'Model': 'Accutor Plus',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 3,
#   ' Minimum Price Per Nos (RM) ': ' MYR 388,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 446,20 ',
#   'Brand': 'Datascope',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc8'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1601-0301-007'},
#   'Part Description': 'Spo2 Adaptor Cable',
#   'Model': 'Athena Nt+',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 6,
#   ' Minimum Price Per Nos (RM) ': ' MYR 1.800,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2.070,00 ',
#   'Brand': 'S&W',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebc9'),
#   'Item Code': 'BP0012',
#   'Item Description': 'Filters',
#   'Part No': {'': '01-1907-0201-007'},
#   'Part Description': 'AMEDA, 7 Shut Off Filter',
#   'Model': 'Com 80221',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 59,
#   ' Minimum Price Per Nos (RM) ': ' MYR 7,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 8,05 ',
#   'Brand': 'AMEDA, Egnell',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 45},
#  {'_id': ObjectId('6620e804924de81c6030ebca'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1603-0601-003'},
#   'Part Description': 'Extension Cable',
#   'Model': 'Cosmo 7100',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 670,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 770,50 ',
#   'Brand': 'NOVAMETRIX',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebcb'),
#   'Item Code': 'BP0004',
#   'Item Description': 'Cables/ Lead Wires (or any part of it)',
#   'Part No': {'': '01-1603-0602-003'},
#   'Part Description': 'Connector Cable (Db-9/Oxysnap)',
#   'Model': 'Cosmo 7100',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 350,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 402,50 ',
#   'Brand': 'NOVAMETRIX',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebcc'),
#   'Item Code': 'BP0023',
#   'Item Description': 'PPM/ Service/Maintenance/ Repair Kits',
#   'Part No': {'': '01-2203-0101-006'},
#   'Part Description': 'SECHRIST Ppm Service Kit',
#   'Model': 'Iv100b',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 10,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 11,50 ',
#   'Brand': 'SECHRIST',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030ebcd'),
#   'Item Code': 'BP0017',
#   'Item Description': 'Membranes',
#   'Part No': {'': '01-0903-0205-001'},
#   'Part Description': 'Membrane Sheet',
#   'Model': 'Top 5200',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 70,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 80,50 ',
#   'Brand': 'TOP',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebce'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1301-0201-001'},
#   'Part Description': 'Bulb OSRAM 5001BA15s 6V 10W',
#   'Model': 'Leitz',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 24,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 27,60 ',
#   'Brand': 'LEITZ',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 7},
#  {'_id': ObjectId('6620e804924de81c6030ebcf'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1505-0201-001'},
#   'Part Description': 'Bulb 24V 40W',
#   'Model': 'Ha58s',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 77,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 88,55 ',
#   'Brand': 'DAI-ICHE',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebd0'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1505-0701-001'},
#   'Part Description': 'Bulb Halogen 50W 24V',
#   'Model': 'Ax 4',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 15,
#   ' Minimum Price Per Nos (RM) ': ' MYR 18,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 20,70 ',
#   'Brand': 'ANGENIEUX/OSRAM',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebd1'),
#   'Item Code': 'BP0003',
#   'Item Description': 'Bulbs/ Lamps',
#   'Part No': {'': '01-1505-0303-001'},
#   'Part Description': 'Bulb 24v 100w',
#   'Model': 'X10df Duo V Fs',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Fast Moving Item',
#   'Location': 'Company Site Office',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 1,
#   'Max Nos': 20,
#   ' Minimum Price Per Nos (RM) ': ' MYR 50,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 57,50 ',
#   'Brand': 'Angineuze',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebd2'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-1601-0103-009'},
#   'Part Description': 'Ic',
#   'Model': '78353a',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 10,
#   ' Minimum Price Per Nos (RM) ': ' MYR 182,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 209,30 ',
#   'Brand': 'HEWLETT PACKARD',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030ebd3'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0901-0303-018'},
#   'Part Description': 'AIR SHIELD Grommet Access',
#   'Model': 'C300',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 7,
#   ' Minimum Price Per Nos (RM) ': ' MYR 120,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 138,00 ',
#   'Brand': 'Air Shields',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 7},
#  {'_id': ObjectId('6620e804924de81c6030ebd4'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-0901-0304-009'},
#   'Part Description': 'AIR SHIELD Iris Sleeve (Pack Of 4)',
#   'Model': 'C400 & 450',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 106,
#   ' Minimum Price Per Nos (RM) ': ' MYR 18,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 20,70 ',
#   'Brand': 'Air Shields',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 18},
#  {'_id': ObjectId('6620e804924de81c6030ebd5'),
#   'Item Code': 'BP0011',
#   'Item Description': 'Equipment Specific Parts',
#   'Part No': {'': '01-1303-0101-001'},
#   'Part Description': 'Htc Protection Sheild For Hps 101',
#   'Model': 'Chemopharm',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 1,
#   ' Minimum Price Per Nos (RM) ': ' MYR 18,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 20,70 ',
#   'Brand': 'Chemopharm',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebd6'),
#   'Item Code': 'BP0027',
#   'Item Description': 'Switchs/ Knobs/Buttons',
#   'Part No': {'': '01-1303-0101-002'},
#   'Part Description': 'MEDELA DOUBLE ROCKER SWITCH MADELA',
#   'Model': 'Chemopharm',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 1,
#   ' Minimum Price Per Nos (RM) ': ' MYR 70,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 80,50 ',
#   'Brand': 'Chemopharm',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030ebd7'),
#   'Item Code': 'BP0016',
#   'Item Description': 'Mechanical Components',
#   'Part No': {'': '01-1303-0202-001'},
#   'Part Description': 'MEDELA SQUARE NUT MADELA',
#   'Model': 'Mls 1200',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 2,
#   ' Minimum Price Per Nos (RM) ': ' MYR 18,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 20,70 ',
#   'Brand': 'Milestone',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 1},
#  {'_id': ObjectId('6620e804924de81c6030ebd8'),
#   'Item Code': 'BP0020',
#   'Item Description': 'Paddles/ Wheels/ Castors/Brakes',
#   'Part No': {'': '01-1402-0301-001'},
#   'Part Description': 'CASTOR WHEEL WITH SCREW HEAD 2',
#   'Model': 'Bp8000c',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'One Off',
#   'Location': 'Others',
#   'Specify': 'Vendor - By Purchase Order',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 50,
#   ' Minimum Price Per Nos (RM) ': ' MYR 3,50 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 4,03 ',
#   'Brand': 'Press Mate',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 0},
#  {'_id': ObjectId('6620e804924de81c6030ebd9'),
#   'Item Code': 'BP0028',
#   'Item Description': 'Transducers/ Probes',
#   'Part No': {'': '01-0303-0201-003'},
#   'Part Description': 'CARDIOTOCOGRAPH 1.5Mhz Ultrasound Transducer (Yellow)',
#   'Model': 'Sonicaid',
#   'Unit Of Measurement': 'Unit',
#   'Spare Part Type': 'Just In Time',
#   'Location': 'Centralized',
#   'Part Category': 'Biomedical',
#   'Is Expiry date Required': 'No',
#   'Min Nos': 0,
#   'Max Nos': 5,
#   ' Minimum Price Per Nos (RM) ': ' MYR 2.398,00 ',
#   ' Maximum Price Per Nos (RM) ': ' MYR 2.757,70 ',
#   'Brand': 'Oxford Instrument',
#   'Status': 'Active',
#   'Expiry Age (In Month)': 0,
#   'Current Stock Level': 2}]

# %%
# Step 1: Create embeddings and store in a new "InventoryEmbeddings" collection

embeddings = emb_model.encode(data)
embeddings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Step 1: Create embeddings and store in a new "InventoryEmbeddings" collection
# ----> 3 embeddings = emb_model.encode(data)
#       4 embeddings
#
# File c:\Personal Projects\14_RAG_for_structured_data\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:361, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     358 self.to(device)
#     360 all_embeddings = []
# --> 361 length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     362 sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     364 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#
# File c:\Personal Projects\14_RAG_for_structured_data\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:361, in <listcomp>(.0)
#     358 self.to(device)
#     360 all_embeddings = []
# --> 361 length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     362 sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     364 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#
# File c:\Personal Projects\14_RAG_for_structured_data\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:920, in SentenceTransformer._text_length(self, text)
#     913 """
#     914 Help function to get the length for the input text. Text can be either
#     915 a list of ints (which means a single text as input), or a tuple of list of ints
#     916 (representing several text inputs to the model).
#     917 """
#     919 if isinstance(text, dict):  # {key: value} case
# --> 920     return len(next(iter(text.values())))
#     921 elif not hasattr(text, "__len__"):  # Object has no len() method
#     922     return 1
#
# TypeError: object of type 'ObjectId' has no len()

# %%
# Step 2: Store embeddings in a vector store (e.g. FAISS or Chroma)

vectorstore = Chroma.from_documents(docs)

# %%
# Step 3: Store embeddings in a vector store (e.g. FAISS)
# Step 3:
